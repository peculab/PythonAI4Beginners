# %% [markdown]
# <a href="https://colab.research.google.com/github/peculab/PythonAI4Beginners/blob/main/%E7%AC%AC%E5%9B%9B%E9%80%B1_%E8%81%8A%E5%A4%A9%E6%A9%9F%E5%99%A8%E4%BA%BA_Part2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://ai.google.dev/
#
# https://ai.google.dev/gemini-api/docs/quickstart?lang=python

# %%
from google.colab import userdata
apikey = userdata.get('GEMINI_API_KEY')

# %%
text = ' 李小花 國 90 英 86 數 74 社 90 自 75; 114-1 學期，八年級，女生; 請針對這樣的學生成績，給我一段學習摘要; 我是一個非常忙得家長，看不了這麼多字，給我一個五分鐘內可以消化的圖表和文字摘要'

# %%
import google.generativeai as genai
genai.configure(api_key = apikey)
model = genai.GenerativeModel("gemini-3-flash-preview")
response = model.generate_content(text)
print(response.text)
# Out:
# 這是一份為忙碌家長設計的**「1分鐘快速診斷報告」**。
#
# ### 📊 成績分析圖表
#
# | 科目 | 分數 | 狀態 | 屬性 |
# | :--- | :--- | :--- | :--- |
# | **國文** | **90** | 🌟 優異 | 文科優勢明顯 |
# | **社會** | **90** | 🌟 優異 | 記憶與理解力強 |
# | **英文** | **86** | 👍 前段 | 穩定發揮 |
# | **自然** | **75** | ⚠️ 需關注 | 八上理化基礎期 |
# | **數學** | **74** | ⚠️ 需關注 | 邏輯應用待加強 |
#
# ---
#
# ### 💡 核心摘要（30秒讀完）
#
# 1.  **文強理弱型：** 小花具有極佳的語文天賦與社會科理解力，這類學生通常具備良好的閱讀習慣與感性思維。
# 2.  **八年級轉折點：** 八年級新加入「理化」，目前 75 分顯示她對抽象的科學概念（如：原子、密度、力學）感到吃力。
# 3.  **數學連動效應：** 數學 74 分會直接影響到理化的計算，這是目前的學習瓶頸所在。
#
# ---
#
# ### 🚀 給家長的 3 個行動建議（5分鐘決策）
#
# *   **🏆 肯定優勢：** 讚美她的國文與社會表現，這能維持她的學習自信，避免因為理科挫折而放棄全盤。
# *   **🔍 理化補強：** 八年級理化是關鍵。建議確認她是「聽不懂觀念」還是「不會計算」。若是前者，需要補習或尋求輔助教材；若是後者，需增加數學練習。
# *   **⚖️ 時間配比：** 建議考前複習時間分配比例改為：**數(40%)、自(30%)、英(10%)、國社(20%)**。目前文科已穩，應將主力移往理科止跌。
#
# **【一句話總結】**：小花是文科小才女，目前的挑戰在於**理化初體驗的適應**，只要守住數學基本盤，整體成績依然非常優秀。

# %%
def translate_text(text, target_language):
    prompt = f"Translate the following text to {target_language}: {text}"
    response = model.generate_content(prompt)
    return response.text

# %%
def chat_bot():
    print("Welcome to the translation chatbot!")
    print("Type 'exit' to quit.")

    target_language = input("Please specify the target language (e.g., French, Spanish, Chinese): ")

    while True:
        user_input = input("Enter the text you want to translate: ")

        if user_input.lower() == "exit":
            print("Goodbye!")
            break

        translation = translate_text(user_input, target_language)
        print(f"Translation to {target_language}: {translation}")

# %%
chat_bot()
